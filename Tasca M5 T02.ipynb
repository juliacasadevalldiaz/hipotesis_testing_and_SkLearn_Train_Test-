# %% [markdown]
# # Tasca M5 T02
#
# ### Descripció
# ### **Exercicis de Train-Test amb ScikitLearn a partir d'un dataset amb informació sobre les vivendes de Houston.**
#
# ### - **Exercici 1**
# Parteix el conjunt de dades adjunt en train i test. Estudia els dos conjunts per separat, a nivell descriptiu.
# També adjunt trobaràs una descripció de les diferents variables del dataset:

# %%
import pandas as pd
data = pd.read_csv("C:/Users/julia/DATA SCIENCE IT/SPRINT 5/T2/housing data.csv", sep=",")

# %%
data
# Out:
#      0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0    0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1    0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2    0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3    0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4    0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
# ..       ...    ...    ... ..     ...     ...    ...     ... ..    ...    ...
# 500  0.06263    0.0  11.93  0   0.573   6.593   69.1  2.4786  1  273.0   21.0
# 501  0.04527    0.0  11.93  0   0.573   6.120   76.7  2.2875  1  273.0   21.0
# 502  0.06076    0.0  11.93  0   0.573   6.976   91.0  2.1675  1  273.0   21.0
# 503  0.10959    0.0  11.93  0   0.573   6.794   89.3  2.3889  1  273.0   21.0
# 504  0.04741    0.0  11.93  0   0.573   6.030   80.8  2.5050  1  273.0   21.0
#
#      396.90  4.98  24.00
# 0    396.90  9.14   21.6
# 1    392.83  4.03   34.7
# 2    394.63  2.94   33.4
# 3    396.90  5.33   36.2
# 4    394.12  5.21   28.7
# ..      ...   ...    ...
# 500  391.99  9.67   22.4
# 501  396.90  9.08   20.6
# 502  396.90  5.64   23.9
# 503  393.45  6.48   22.0
# 504  396.90  7.88   11.9
#
# [505 rows x 14 columns]

# %% [markdown]
# El dataset no té els noms de les columnes es per aixo que el torno a crear pero aquest cop li atribueixo les columnes:

# %%
data.columns=["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT","MEDV"]
data.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 1  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 2  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 3  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 4  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 5  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 6  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 7  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 8  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 9  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     17.8  396.90   9.14  21.6
# 1     17.8  392.83   4.03  34.7
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     18.7  394.12   5.21  28.7
# 5     15.2  395.60  12.43  22.9
# 6     15.2  396.90  19.15  27.1
# 7     15.2  386.63  29.93  16.5
# 8     15.2  386.71  17.10  18.9
# 9     15.2  392.52  20.45  15.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     505 non-null    float64
#  1   ZN       505 non-null    float64
#  2   INDUS    505 non-null    float64
#  3   CHAS     505 non-null    int64
#  4   NOX      505 non-null    float64
#  5   RM       505 non-null    float64
#  6   AGE      505 non-null    float64
#  7   DIS      505 non-null    float64
#  8   RAD      505 non-null    int64
#  9   TAX      505 non-null    float64
#  10  PTRATIO  505 non-null    float64
#  11  B        505 non-null    float64
#  12  LSTAT    505 non-null    float64
#  13  MEDV     505 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# El dataframe esta net, per tant no cal modificar més.

# %%
data.describe().T
# Out:
#          count        mean         std        min        25%        50%  \
# CRIM     505.0    3.620667    8.608572    0.00906    0.08221    0.25915
# ZN       505.0   11.350495   23.343704    0.00000    0.00000    0.00000
# INDUS    505.0   11.154257    6.855868    0.46000    5.19000    9.69000
# CHAS     505.0    0.069307    0.254227    0.00000    0.00000    0.00000
# NOX      505.0    0.554728    0.115990    0.38500    0.44900    0.53800
# RM       505.0    6.284059    0.703195    3.56100    5.88500    6.20800
# AGE      505.0   68.581584   28.176371    2.90000   45.00000   77.70000
# DIS      505.0    3.794459    2.107757    1.12960    2.10000    3.19920
# RAD      505.0    9.566337    8.707553    1.00000    4.00000    5.00000
# TAX      505.0  408.459406  168.629992  187.00000  279.00000  330.00000
# PTRATIO  505.0   18.461782    2.162520   12.60000   17.40000   19.10000
# B        505.0  356.594376   91.367787    0.32000  375.33000  391.43000
# LSTAT    505.0   12.668257    7.139950    1.73000    7.01000   11.38000
# MEDV     505.0   22.529901    9.205991    5.00000   17.00000   21.20000
#
#                75%       max
# CRIM       3.67822   88.9762
# ZN        12.50000  100.0000
# INDUS     18.10000   27.7400
# CHAS       0.00000    1.0000
# NOX        0.62400    0.8710
# RM         6.62500    8.7800
# AGE       94.10000  100.0000
# DIS        5.21190   12.1265
# RAD       24.00000   24.0000
# TAX      666.00000  711.0000
# PTRATIO   20.20000   22.0000
# B        396.21000  396.9000
# LSTAT     16.96000   37.9700
# MEDV      25.00000   50.0000

# %% [markdown]
# Procedim a estudiar la correlació entre les variables:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(),annot=True,fmt=".2f",cmap='RdBu_r')
plt.show()

# %% [markdown]
# ATRIBUTS
#
# - **CRIM:** Taxa de criminalitat per càpita per poble.
# - **ZN:** Proporció de terreny residencial zonificat per a terrenys de més de 25,000 peus quadrats.
# - **INDUS:** Proporció d'acres de negocis no minoristes per poble.
# - **CHAS:** Variable fictícia del riu Charles (= 1 si l'àrea limita amb el riu; 0 en cas contrari).
# - **NOX:** Concentració d'òxids de nitrogen (parts per 10 milions).
# - **RM:** Nombre mitjà d'habitacions per habitatge.
# - **AGE:** Proporció d'unitats ocupades pel propietari construïdes abans de 1940.
# - **DIS:** Distàncies ponderades a cinc centres d'ocupació a Boston.
# - **RAD:** Índex d'accessibilitat a carreteres radials.
# - **TAX:** Taxa d'impostos a la propietat de valor total per 10,000 dòlars.
# - **PTRATIO:** Relació alumne-mestre per poble.
# - **B:** 1000(Bk - 0.63)^2 on Bk és la proporció de població negra per poble.
# - **LSTAT:** % d'estatus més baix de la població.
# - **MEDV:** Valor mitjà de les vivendes ocupades pel propietari en milers de dòlars (1,000 $).

# %% [markdown]
# La figura superior, és un mapa de calor de la matriu de correlació de les nostres dades. Cada cel·la de la matriu conté el coeficient de correlació. El coeficient pot variar entre -1 i 1: un valor proper a 1 indica una correlació positiva, prop a -1 una correlació negativa i prop a 0 una correlació feble o inexistenta. Els colors també indiquen el grau de correlació, el color blau representa correlacions inversament proporcionals (negatives) i els vermells indiquen una relació directament proporcional (positiva).
#
# Els resultats mostren que el coeficient de correlació entre RAD i TAX es de 0.91, indicant que hi ha una correlació molt gran entre els impostos a la propietat i l'index d'accessibilitat  a carreteres radials. Es tracta d'una correlació directament proporcional(color vermell). Mentre que, entre les variables "MEDV" i "LSTAT" hi ha una correlació inversament proporcional.

# %% [markdown]
# **Procedim al cos del exercici:**
#
# **INTRODUCCIÓ:**
# -  El Train-Test Split s'utilitza per avaluar el rendiment d'un model. La seva funció principal és dividir el conjunt de dades disponible en dues parts: un conjunt d'entrenament (Train Set) i un conjunt de prova (Test Set).
# -  'MEDV' serà la variable que utilitzaré en aquest exemple, com a target, per tal de predir-la.
# -  La variable *x/features* seran totes les variables excepte "MEDV". I la variable *y/target* (objectiu) serà "MEDV".

# %%
from sklearn.model_selection import train_test_split

X = data.drop('MEDV', axis=1)
y = data['MEDV']
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (338, 13) (167, 13) (338,) (167,)

# %% [markdown]
# Com s'indica, hi ha 338 registres dins del training set (67%) i 167 registres dins del test set (33%), tal i com s'ha especificat a la funció. Vegeu a continuació:

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 477  10.23300   0.0  18.10     0  0.614  6.185   96.7  2.1705   24  666.0
# 26    0.95577   0.0   8.14     0  0.538  6.047   88.8  4.4534    4  307.0
# 7     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 457   7.75223   0.0  18.10     0  0.713  6.301   83.7  2.7831   24  666.0
# 108   0.26363   0.0   8.56     0  0.520  6.229   91.2  2.5451    5  384.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 106   0.13117   0.0   8.56     0  0.520  6.127   85.2  2.1224    5  384.0
# 270   0.16211  20.0   6.96     0  0.464  6.240   16.3  4.4290    3  223.0
# 348   0.02899  40.0   1.25     0  0.429  6.939   34.5  8.7921    1  335.0
# 435  14.42080   0.0  18.10     0  0.740  6.461   93.3  2.0026   24  666.0
# 102   0.21161   0.0   8.56     0  0.520  6.137   87.4  2.7147    5  384.0
#
#      PTRATIO       B  LSTAT
# 477     20.2  379.70  18.03
# 26      21.0  306.38  17.28
# 7       15.2  386.63  29.93
# 457     20.2  272.21  16.23
# 108     20.9  391.23  15.55
# ..       ...     ...    ...
# 106     20.9  387.69  14.09
# 270     18.6  396.90   6.59
# 348     19.7  389.85   5.89
# 435     20.2   27.49  18.05
# 102     20.9  394.47  13.44
#
# [338 rows x 13 columns]

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 173  0.08447   0.0   4.05     0  0.510  5.859  68.7  2.7019    5  296.0
# 274  0.09604  40.0   6.41     0  0.447  6.854  42.8  4.2673    4  254.0
# 490  0.10574   0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711.0
# 72   0.19539   0.0  10.81     0  0.413  6.245   6.2  5.2873    4  305.0
# 305  0.07503  33.0   2.18     0  0.472  7.420  71.9  3.0992    7  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 110  0.10084   0.0  10.01     0  0.547  6.715  81.6  2.6775    6  432.0
# 320  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287.0
# 265  0.78570  20.0   3.97     0  0.647  7.014  84.6  2.1329    5  264.0
# 29   1.13081   0.0   8.14     0  0.538  5.713  94.1  4.2330    4  307.0
# 262  0.82526  20.0   3.97     0  0.647  7.327  94.5  2.0788    5  264.0
#
#      PTRATIO       B  LSTAT
# 173     16.6  393.23   9.64
# 274     17.6  396.90   2.98
# 490     20.1  390.11  18.07
# 72      19.2  377.17   7.54
# 305     18.4  396.90   6.47
# ..       ...     ...    ...
# 110     17.8  395.59  10.16
# 320     19.6  396.90   6.87
# 265     13.0  384.07  14.79
# 29      21.0  360.17  22.60
# 262     13.0  393.42  11.25
#
# [167 rows x 13 columns]

# %% [markdown]
# Un cop dividits, training set i test set, procedeixo a estudiar els cojunts per separat.
# Primer descriptivament

# %%
X_train.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  338.000000  338.000000  338.000000  338.000000  338.000000  338.000000
# mean     3.681673   12.278107   11.433757    0.076923    0.559890    6.318112
# std      8.568673   23.813903    7.038021    0.266864    0.118774    0.737290
# min      0.009060    0.000000    1.210000    0.000000    0.385000    3.863000
# 25%      0.081900    0.000000    5.130000    0.000000    0.448250    5.887250
# 50%      0.316800    0.000000    9.900000    0.000000    0.538000    6.214000
# 75%      3.846485   20.000000   18.100000    0.000000    0.647000    6.669250
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  338.000000  338.000000  338.000000  338.000000  338.000000  338.000000
# mean    68.739645    3.744025    9.866864  415.917160   18.279882  356.375799
# std     28.160209    2.178654    8.840326  169.030151    2.236097   91.095793
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.225000    2.013475    4.000000  281.750000   16.600000  374.462500
# 50%     77.750000    2.905900    5.000000  352.000000   18.650000  391.260000
# 75%     93.750000    5.117675   24.000000  666.000000   20.200000  396.192500
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  338.000000
# mean    12.641834
# std      7.283409
# min      1.730000
# 25%      7.042500
# 50%     11.395000
# 75%     16.717500
# max     37.970000

# %%
X_test.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  167.000000  167.000000  167.000000  167.000000  167.000000  167.000000
# mean     3.497193    9.473054   10.588563    0.053892    0.544280    6.215138
# std      8.713344   22.313636    6.455015    0.226484    0.109745    0.624991
# min      0.013810    0.000000    0.460000    0.000000    0.394000    3.561000
# 25%      0.085770    0.000000    5.190000    0.000000    0.451000    5.881500
# 50%      0.224380    0.000000    8.560000    0.000000    0.524000    6.152000
# 75%      2.037660    0.000000   18.100000    0.000000    0.597000    6.478000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.040000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  167.000000  167.000000  167.000000  167.000000  167.000000  167.000000
# mean    68.261677    3.896533    8.958084  393.365269   18.829940  357.036766
# std     28.291079    1.958777    8.425687  167.303971    1.960591   92.189050
# min      6.000000    1.316300    1.000000  188.000000   12.600000    6.680000
# 25%     43.600000    2.259050    4.000000  277.000000   17.800000  377.005000
# 50%     77.300000    3.665000    5.000000  307.000000   19.200000  392.040000
# 75%     94.400000    5.221500    8.000000  437.000000   20.200000  396.220000
# max    100.000000   10.585700   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  167.000000
# mean    12.721737
# std      6.861565
# min      1.980000
# 25%      6.995000
# 50%     11.280000
# 75%     17.270000
# max     34.410000

# %% [markdown]
# Faig un histograma amb les KDEs per comparar les distribucions:

# %%
plt.figure(figsize=(14, 8))
for i, feature in enumerate(X_train.columns):
    plt.subplot(3, 5, i + 1)
    sns.histplot(X_train[feature], bins=20, kde=True, label='Train', color='blue')
    sns.histplot(X_test[feature], bins=20, kde=True, label='Test', color='orange')
    plt.title(feature)
    plt.legend()
    plt.tight_layout()
    plt.show

# %% [markdown]
# Pel que veig en els grafics superiors, el test_test es comporta de forma molt semblant al train_set.

# %%
# Boxplots per comparar les distribucions:
plt.figure(figsize=(16, 8))
for i, feature in enumerate(X_train.columns):
    plt.subplot(3, 5, i + 1)
    sns.boxplot(x='dataset', y=feature, data=pd.concat([X_train.assign(dataset='Train'), X_test.assign(dataset='Test')]))
    plt.title(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# Després d'analitzar i comparar els conjunts graficament es podria dir que no hi ha diferencies significatives entre els dos conjunts.
# Procedeixo a fer un test d'hipotesis per comprovar analiticament que no existeixen diferencies:
#
# **Test de Shapiro-Wilk:**
# - **Hipòtesi Nul·la (H0):** Les dades segueixen una distribució Normal
# - **Hipòtesi Alternativa (H1):** Les dades NO segueixen una distribució Normal

# %%
from scipy import stats
from scipy.stats import shapiro

for data in X_train.columns:
    shapiro_test = stats.shapiro(X_train[data])
    print( "variable:", data, "p-valor:", shapiro_test.pvalue)
    if shapiro_test.pvalue > 0.05:
        print("La mostra té una distribució normal.\n")
    else:
        print("La mostra No té una distribució normal.\n")
# Out:
# variable: CRIM p-valor: 8.02277527543557e-31
# La mostra No té una distribució normal.
#
# variable: ZN p-valor: 1.1657296693371255e-27
# La mostra No té una distribució normal.
#
# variable: INDUS p-valor: 3.7957570775209136e-15
# La mostra No té una distribució normal.
#
# variable: CHAS p-valor: 6.08812539273108e-34
# La mostra No té una distribució normal.
#
# variable: NOX p-valor: 2.1745252820615235e-10
# La mostra No té una distribució normal.
#
# variable: RM p-valor: 5.263315117076672e-08
# La mostra No té una distribució normal.
#
# variable: AGE p-valor: 6.701938130978732e-15
# La mostra No té una distribució normal.
#
# variable: DIS p-valor: 3.759911490226059e-15
# La mostra No té una distribució normal.
#
# variable: RAD p-valor: 1.9660533821790396e-24
# La mostra No té una distribució normal.
#
# variable: TAX p-valor: 4.549592113727276e-19
# La mostra No té una distribució normal.
#
# variable: PTRATIO p-valor: 1.6690865540808925e-13
# La mostra No té una distribució normal.
#
# variable: B p-valor: 3.3309402254844115e-30
# La mostra No té una distribució normal.
#
# variable: LSTAT p-valor: 8.85872538519683e-12
# La mostra No té una distribució normal.

# %%
for data in X_test.columns:
    shapiro_test = stats.shapiro(X_test[data])
    print( "variable:", data, "p-valor:", shapiro_test.pvalue)
    if shapiro_test.pvalue > 0.05:
        print("La mostra té una distribució normal.\n")
    else:
        print("La mostra No té una distribució normal.\n")
# Out:
# variable: CRIM p-valor: 1.144984524709475e-22
# La mostra No té una distribució normal.
#
# variable: ZN p-valor: 7.669170415136213e-22
# La mostra No té una distribució normal.
#
# variable: INDUS p-valor: 6.193996426873127e-08
# La mostra No té una distribució normal.
#
# variable: CHAS p-valor: 7.904255615227111e-26
# La mostra No té una distribució normal.
#
# variable: NOX p-valor: 5.467513020107617e-08
# La mostra No té una distribució normal.
#
# variable: RM p-valor: 0.00010799087613122538
# La mostra No té una distribució normal.
#
# variable: AGE p-valor: 1.218950496095772e-09
# La mostra No té una distribució normal.
#
# variable: DIS p-valor: 1.8727902784121397e-07
# La mostra No té una distribució normal.
#
# variable: RAD p-valor: 2.4318497895405724e-18
# La mostra No té una distribució normal.
#
# variable: TAX p-valor: 7.457631110959276e-14
# La mostra No té una distribució normal.
#
# variable: PTRATIO p-valor: 1.0192895416594183e-09
# La mostra No té una distribució normal.
#
# variable: B p-valor: 3.6062891140326355e-22
# La mostra No té una distribució normal.
#
# variable: LSTAT p-valor: 1.3863023013982456e-05
# La mostra No té una distribució normal.

# %% [markdown]
# Tal i com indiquen els test de Shapiro concluim que ninguna variable segueix una distribució normal. Per comparar les dos mostres es pot utilizar el test de U de Mann-Whitney, que es una proba no parametrica utilitzada per comparar dues mostres independents i no requereix que hi hagi una distribució específica de les dades, per tant ideal en el nostre cas.
#
# **Test de U de Mann-Whitney**
#
# - **Hipòtesi Nul·la (H0):** La distribució de les dues mostres és la mateixa
# - **Hipòtesi Alternativa (H1):** Hi ha diferències significatives entre les dues mostres

# %%
from scipy.stats import mannwhitneyu

for variable in X_train.columns:
    statistic, p_value = mannwhitneyu(X_train[variable], X_test[variable])
    
    print(f"Variable: {variable}")
    print(f"Estadístic U: {statistic}")
    print(f"p-valor: {p_value}")
    
    if p_value < 0.05:
        print("Hi ha diferències significatives entre les dues mostres.\n")
    else:
        print("La distribució entre les dues mostres és la mateixa.\n")
# Out:
# Variable: CRIM
# Estadístic U: 29397.0
# p-valor: 0.4468692614076042
# La distribució entre les dues mostres és la mateixa.
#
# Variable: ZN
# Estadístic U: 29951.0
# p-valor: 0.1483471037459131
# La distribució entre les dues mostres és la mateixa.
#
# Variable: INDUS
# Estadístic U: 29723.5
# p-valor: 0.3264384279490856
# La distribució entre les dues mostres és la mateixa.
#
# Variable: CHAS
# Estadístic U: 28873.0
# p-valor: 0.3385528575786414
# La distribució entre les dues mostres és la mateixa.
#
# Variable: NOX
# Estadístic U: 30146.5
# p-valor: 0.21249282704915362
# La distribució entre les dues mostres és la mateixa.
#
# Variable: RM
# Estadístic U: 30466.5
# p-valor: 0.14597937575226044
# La distribució entre les dues mostres és la mateixa.
#
# Variable: AGE
# Estadístic U: 28375.0
# p-valor: 0.9217491107436979
# La distribució entre les dues mostres és la mateixa.
#
# Variable: DIS
# Estadístic U: 25949.5
# p-valor: 0.14066220141965025
# La distribució entre les dues mostres és la mateixa.
#
# Variable: RAD
# Estadístic U: 30330.5
# p-valor: 0.1631613505292837
# La distribució entre les dues mostres és la mateixa.
#
# Variable: TAX
# Estadístic U: 30712.5
# p-valor: 0.1033855878439596
# La distribució entre les dues mostres és la mateixa.
#
# Variable: PTRATIO
# Estadístic U: 24450.5
# p-valor: 0.013415306065934413
# Hi ha diferències significatives entre les dues mostres.
#
# Variable: B
# Estadístic U: 27547.5
# p-valor: 0.659582308007368
# La distribució entre les dues mostres és la mateixa.
#
# Variable: LSTAT
# Estadístic U: 27421.5
# p-valor: 0.6036235895195772
# La distribució entre les dues mostres és la mateixa.

# %% [markdown]
# Donat els resultats, podem dir que la funcio train_test_split ha funcionat prou bé, ja que no s'observen diferenecies significatives entre train i test menys en una variable que si que hi ha diferencies significatives entre les dues distribucions: 'PTRATIO'.

# %% [markdown]
# ### - **Exercici 2**
# **Aplica algun procés de transformació (estandarditzar les dades numèriques, crear columnes dummies, polinomis...).**

# %% [markdown]
# Mirem com son les variables:

# %%
X_train.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# dtype: object

# %% [markdown]
# Totes son float(decimals) menys RAD i CHAS que sonn int(sense decimals).

# %% [markdown]
# Vull saber quines variables tenen outliers (valors atipics), per si s'ha d'aplicar el Robust scale.

# %%
columnes=X_train.columns.tolist()
for i in columnes:
    sns.boxplot(data=X_train, y=i) 
    plt.title("Outlier variable "+ i, size=15)
    plt.show()

# %% [markdown]
# Les variables: CRIM, ZN, CHAS, RM, DIS, B i LSTAT del training set tenen outliers.

# %%
columnes=X_test.columns.tolist()
for i in columnes:
    sns.boxplot(data=X_test, y=i) 
    plt.title("Outlier variable "+ i, size=15)
    plt.show()

# %% [markdown]
# Les variables: CRIM, ZN, CHAS,NOX, RM, DIS, RAD, TAX, PTRATIO, B i LSTAT del X_test tenen outliers.
#
# Un cop sé quines variables tenen outliers i quines no, faré el Robust Scale a totes les variables del training set amb outliers ( CRIM, ZN, RM, DIS, B i LSTAT ) menys CHAS perque es binaria. La transformació es fa en el training set perque representa que el test set no el conec. Pero abans faig una copia per tenir els valors de X_train originals (sense transformacions).

# %%
X_train_transformat = X_train.copy() 
X_train_transformat.head(10)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 477  10.23300   0.0  18.10     0  0.614  6.185   96.7  2.1705   24  666.0
# 26    0.95577   0.0   8.14     0  0.538  6.047   88.8  4.4534    4  307.0
# 7     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 457   7.75223   0.0  18.10     0  0.713  6.301   83.7  2.7831   24  666.0
# 108   0.26363   0.0   8.56     0  0.520  6.229   91.2  2.5451    5  384.0
# 37    0.17505   0.0   5.96     0  0.499  5.966   30.2  3.8473    5  279.0
# 157   1.34284   0.0  19.58     0  0.605  6.066  100.0  1.7573    5  403.0
# 471   3.56868   0.0  18.10     0  0.580  6.437   75.0  2.8965   24  666.0
# 118   0.14476   0.0  10.01     0  0.547  5.731   65.2  2.7592    6  432.0
# 114   0.17134   0.0  10.01     0  0.547  5.928   88.2  2.4631    6  432.0
#
#      PTRATIO       B  LSTAT
# 477     20.2  379.70  18.03
# 26      21.0  306.38  17.28
# 7       15.2  386.63  29.93
# 457     20.2  272.21  16.23
# 108     20.9  391.23  15.55
# 37      19.2  393.43  10.13
# 157     14.7  353.89   6.43
# 471     20.2  393.37  14.36
# 118     17.8  391.50  13.61
# 114     17.8  344.91  15.76

# %%
from sklearn import preprocessing 
X_train_transformat[["CRIM", "ZN", "RM", "DIS", "B", "LSTAT"]]=preprocessing.RobustScaler().fit_transform(X_train_transformat[["CRIM", "ZN", "RM", "DIS", "B", "LSTAT"]])
X_train_transformat.head(10)
# Out:
#          CRIM     ZN  INDUS  CHAS    NOX        RM    AGE       DIS  RAD  \
# 477  2.634075  0.000  18.10     0  0.614 -0.037084   96.7 -0.236905   24
# 26   0.169732  0.000   8.14     0  0.538 -0.213555   88.8  0.498518    4
# 7   -0.028040  0.625   7.87     0  0.524 -0.745524  100.0  1.023194    5
# 457  1.975100  0.000  18.10     0  0.713  0.111253   83.7 -0.039559   24
# 108 -0.014124  0.000   8.56     0  0.520  0.019182   91.2 -0.116230    5
# 37  -0.037654  0.000   5.96     0  0.499 -0.317136   30.2  0.303267    5
# 157  0.272551  0.000  19.58     0  0.605 -0.189258  100.0 -0.370015    5
# 471  0.863808  0.000  18.10     0  0.580  0.285166   75.0 -0.003028   24
# 118 -0.045700  0.000  10.01     0  0.547 -0.617647   65.2 -0.047259    6
# 114 -0.038639  0.000  10.01     0  0.547 -0.365729   88.2 -0.142645    6
#
#        TAX  PTRATIO         B     LSTAT
# 477  666.0     20.2 -0.531983  0.685788
# 26   307.0     21.0 -3.906121  0.608269
# 7    311.0     15.2 -0.213069  1.915762
# 457  666.0     20.2 -5.478601  0.499742
# 108  384.0     20.9 -0.001381  0.429457
# 37   279.0     19.2  0.099862 -0.130749
# 157  403.0     14.7 -1.719742 -0.513178
# 471  666.0     20.2  0.097101  0.306460
# 118  432.0     17.8  0.011045  0.228941
# 114  432.0     17.8 -2.132996  0.451163

# %% [markdown]
# Amb aquesta funció hem eliminat els outliers de les variables del training set.

# %% [markdown]
# Convertiré la variable RAD en dummy perque es categorica:

# %%
X_train['RAD'].value_counts()
# Out:
# 24    93
# 5     78
# 4     65
# 3     22
# 8     18
# 2     18
# 6     17
# 1     14
# 7     13
# Name: RAD, dtype: int64

# %%
dummies = pd.get_dummies(X_train_transformat["RAD"], prefix="RAD")
X_train_transformat = pd.concat([X_train_transformat, dummies], axis=1)
X_train_transformat.head(10)
# Out:
#          CRIM     ZN  INDUS  CHAS    NOX        RM    AGE       DIS  RAD  \
# 477  2.634075  0.000  18.10     0  0.614 -0.037084   96.7 -0.236905   24
# 26   0.169732  0.000   8.14     0  0.538 -0.213555   88.8  0.498518    4
# 7   -0.028040  0.625   7.87     0  0.524 -0.745524  100.0  1.023194    5
# 457  1.975100  0.000  18.10     0  0.713  0.111253   83.7 -0.039559   24
# 108 -0.014124  0.000   8.56     0  0.520  0.019182   91.2 -0.116230    5
# 37  -0.037654  0.000   5.96     0  0.499 -0.317136   30.2  0.303267    5
# 157  0.272551  0.000  19.58     0  0.605 -0.189258  100.0 -0.370015    5
# 471  0.863808  0.000  18.10     0  0.580  0.285166   75.0 -0.003028   24
# 118 -0.045700  0.000  10.01     0  0.547 -0.617647   65.2 -0.047259    6
# 114 -0.038639  0.000  10.01     0  0.547 -0.365729   88.2 -0.142645    6
#
#        TAX  ...     LSTAT  RAD_1  RAD_2  RAD_3  RAD_4  RAD_5  RAD_6  RAD_7  \
# 477  666.0  ...  0.685788      0      0      0      0      0      0      0
# 26   307.0  ...  0.608269      0      0      0      1      0      0      0
# 7    311.0  ...  1.915762      0      0      0      0      1      0      0
# 457  666.0  ...  0.499742      0      0      0      0      0      0      0
# 108  384.0  ...  0.429457      0      0      0      0      1      0      0
# 37   279.0  ... -0.130749      0      0      0      0      1      0      0
# 157  403.0  ... -0.513178      0      0      0      0      1      0      0
# 471  666.0  ...  0.306460      0      0      0      0      0      0      0
# 118  432.0  ...  0.228941      0      0      0      0      0      1      0
# 114  432.0  ...  0.451163      0      0      0      0      0      1      0
#
#      RAD_8  RAD_24
# 477      0       1
# 26       0       0
# 7        0       0
# 457      0       1
# 108      0       0
# 37       0       0
# 157      0       0
# 471      0       1
# 118      0       0
# 114      0       0
#
# [10 rows x 22 columns]

# %% [markdown]
# Fins aqui les transformacions

# %%
X_train_transformat.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# RAD_1        uint8
# RAD_2        uint8
# RAD_3        uint8
# RAD_4        uint8
# RAD_5        uint8
# RAD_6        uint8
# RAD_7        uint8
# RAD_8        uint8
# RAD_24       uint8
# dtype: object

# %% [markdown]
# ### - **Exercici 3**
# **Resumeix les noves columnes generades de manera estadística i gràfica**

# %%
X_train_transformat.describe().T
# Out:
#          count        mean         std         min         25%           50%  \
# CRIM     338.0    0.893823    2.276127   -0.081746   -0.062397  7.372575e-18
# ZN       338.0    0.613905    1.190695    0.000000    0.000000  0.000000e+00
# INDUS    338.0   11.433757    7.038021    1.210000    5.130000  9.900000e+00
# CHAS     338.0    0.076923    0.266864    0.000000    0.000000  0.000000e+00
# NOX      338.0    0.559890    0.118774    0.385000    0.448250  5.380000e-01
# RM       338.0    0.133136    0.942826   -3.006394   -0.417839 -5.676883e-16
# AGE      338.0   68.739645   28.160209    2.900000   45.225000  7.775000e+01
# DIS      338.0    0.269997    0.701841   -0.572225   -0.287490  0.000000e+00
# RAD      338.0    9.866864    8.840326    1.000000    4.000000  5.000000e+00
# TAX      338.0  415.917160  169.030151  187.000000  281.750000  3.520000e+02
# PTRATIO  338.0   18.279882    2.236097   12.600000   16.600000  1.865000e+01
# B        338.0   -1.605348    4.192167  -17.990796   -0.773010  0.000000e+00
# LSTAT    338.0    0.128872    0.752807   -0.998966   -0.449871  9.172350e-17
# RAD_1    338.0    0.041420    0.199555    0.000000    0.000000  0.000000e+00
# RAD_2    338.0    0.053254    0.224873    0.000000    0.000000  0.000000e+00
# RAD_3    338.0    0.065089    0.247048    0.000000    0.000000  0.000000e+00
# RAD_4    338.0    0.192308    0.394698    0.000000    0.000000  0.000000e+00
# RAD_5    338.0    0.230769    0.421950    0.000000    0.000000  0.000000e+00
# RAD_6    338.0    0.050296    0.218879    0.000000    0.000000  0.000000e+00
# RAD_7    338.0    0.038462    0.192593    0.000000    0.000000  0.000000e+00
# RAD_8    338.0    0.053254    0.224873    0.000000    0.000000  0.000000e+00
# RAD_24   338.0    0.275148    0.447251    0.000000    0.000000  0.000000e+00
#
#                 75%         max
# CRIM       0.937603   23.550909
# ZN         1.000000    4.750000
# INDUS     18.100000   27.740000
# CHAS       0.000000    1.000000
# NOX        0.647000    0.871000
# RM         0.582161    3.281330
# AGE       93.750000  100.000000
# DIS        0.712510    2.970363
# RAD       24.000000   24.000000
# TAX      666.000000  711.000000
# PTRATIO   20.200000   22.000000
# B          0.226990    0.259549
# LSTAT      0.550129    2.746770
# RAD_1      0.000000    1.000000
# RAD_2      0.000000    1.000000
# RAD_3      0.000000    1.000000
# RAD_4      0.000000    1.000000
# RAD_5      0.000000    1.000000
# RAD_6      0.000000    1.000000
# RAD_7      0.000000    1.000000
# RAD_8      0.000000    1.000000
# RAD_24     1.000000    1.000000

# %%
X_test.describe().T
# Out:
#          count        mean         std        min        25%        50%  \
# CRIM     167.0    3.497193    8.713344    0.01381    0.08577    0.22438
# ZN       167.0    9.473054   22.313636    0.00000    0.00000    0.00000
# INDUS    167.0   10.588563    6.455015    0.46000    5.19000    8.56000
# CHAS     167.0    0.053892    0.226484    0.00000    0.00000    0.00000
# NOX      167.0    0.544280    0.109745    0.39400    0.45100    0.52400
# RM       167.0    6.215138    0.624991    3.56100    5.88150    6.15200
# AGE      167.0   68.261677   28.291079    6.00000   43.60000   77.30000
# DIS      167.0    3.896533    1.958777    1.31630    2.25905    3.66500
# RAD      167.0    8.958084    8.425687    1.00000    4.00000    5.00000
# TAX      167.0  393.365269  167.303971  188.00000  277.00000  307.00000
# PTRATIO  167.0   18.829940    1.960591   12.60000   17.80000   19.20000
# B        167.0  357.036766   92.189050    6.68000  377.00500  392.04000
# LSTAT    167.0   12.721737    6.861565    1.98000    6.99500   11.28000
#
#                75%       max
# CRIM       2.03766   73.5341
# ZN         0.00000  100.0000
# INDUS     18.10000   27.7400
# CHAS       0.00000    1.0000
# NOX        0.59700    0.8710
# RM         6.47800    8.0400
# AGE       94.40000  100.0000
# DIS        5.22150   10.5857
# RAD        8.00000   24.0000
# TAX      437.00000  711.0000
# PTRATIO   20.20000   22.0000
# B        396.22000  396.9000
# LSTAT     17.27000   34.4100

# %%
plt.figure(figsize=(21, 11))
sns.heatmap(X_train_transformat.corr(),annot=True,fmt=".2f",cmap='RdBu_r')
plt.show()

# %%
plt.figure(figsize=(15
                    , 4))
sns.heatmap(X_test.corr(),annot=True,fmt=".2f",cmap='RdBu_r')
plt.show()

# %%
plt.figure(figsize=(14, 8))
for i, feature in enumerate(X_train_transformat.columns):
    plt.subplot(3, 5, i + 1)
    sns.histplot(X_train_transformat[feature], bins=20, kde=True, label='Train_transformat', color='blue')
    sns.histplot(X_test[feature], bins=20, kde=True, label='Test', color='orange')
    plt.title(feature)
    plt.legend()
    plt.tight_layout()
    plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RAD_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 5
#       3 plt.subplot(3, 5, i + 1)
#       4 sns.histplot(X_train_transformat[feature], bins=20, kde=True, label='Train_transformat', color='blue')
# ----> 5 sns.histplot(X_test[feature], bins=20, kde=True, label='Test', color='orange')
#       6 plt.title(feature)
#       7 plt.legend()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'RAD_1'

# %% [markdown]
# Em dona error a RAD_1 perque no existeix a X_test, ja que son noves columnes del X_train_transformat...
